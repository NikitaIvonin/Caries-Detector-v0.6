# %% [markdown]
# #Добро пожаловать, это модель по выявлению кариеса на рентгеновских снимках Caries-Detector v0.6

# %% [markdown]
# Модель уже была натренерованна на кастомном датасете, в данном ноутбуке представлена возможность вызова уже готовой модели для обнаружения зубов на которых образовался кариес. Данная модель является учебной и пока что не может давать точные медецинские показания, если вам необходимо получить точные сведения рекомендуества проконсультироваться с врачем

# %% [markdown]
# Для запуска модели необходимо скачать данные из гит-репозитория с помощью команды указанной ниже:

# %%
# !git clone https://github.com/NikitaIvonin/Caries-Detector-v0.6.git
# Out:
# Cloning into 'Caries-Detector-v0.6'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 23 (delta 6), reused 6 (delta 0), pack-reused 0
# Receiving objects: 100% (23/23), 5.41 MiB | 19.24 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %% [markdown]
# Псле подключаем зависимости и перезапускаем сеанс google colab если такой вариант будет предложен самой средой

# %%
# !pip install -r Caries-Detector-v0.6/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.4/750.4 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 42.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.5/247.5 kB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 43.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...

# %% [markdown]
# Далее необходимо запустить команду чтобы использовать этот ip при подключении к streamlit(скопируйте этот айпи)

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.172.130.152

# %% [markdown]
# Запустите блок ниже и перейдите по 3-й ссылке(your url is:...) и введите туда скопированный ip
#
# Даллее загрузите фото, нажмите команду запустить, подождите обработки и нажмите кнопку отобразить, чтобы увидить результаты.

# %%
# !streamlit run /content/Caries-Detector-v0.6/app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.172.130.152:8501
#
# npx: installed 22 in 3.523s
# your url is: https://cold-pugs-study.loca.lt
# 2024-04-14 08:02:51.784866: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-14 08:02:51.784919: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-14 08:02:51.786307: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-14 08:02:52.978169: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %% [markdown]
# Проект еще сырой, да и найденых мою данных пока мало, поэтому, если вы хотите поучаствовать в проекте, получить ссылку на мой датасет или у вас есть какие-то вопросы или замечания, просьба обращаться по адресу nivonin4@gmail.com
